# %%
# %run "Import.ipynb"

# Abfrage und Anzeigen von Daten aus den SQL-Tabellen. Auf 10 Reihen limitiert.
query = "SELECT * FROM training_data LIMIT 10"
result = data_importer.query_data(query)
print("Training Data")
print(result)

query = "SELECT * FROM ideal_functions LIMIT 10"
result = data_importer.query_data(query)
print("Ideal Functions")
print(result)

query = "SELECT * FROM test_data LIMIT 10"
result = data_importer.query_data(query)
print("Test Data")
print(result)
# Out:
# DB-Verbindung erfolgreich hergestellt.
# SQL-DB erstellt
# Daten erfolgreich importiert zu training_data.
# Daten erfolgreich importiert zu ideal_functions.
# Daten erfolgreich importiert zu test_data.
# SQL-Tabellen erstellt
# Training Data
#       x          y1         y2        y3         y4
# 0 -20.0  100.216064 -19.757296  0.346114  19.776287
# 1 -19.9   99.894684 -19.702820  0.617864  19.789793
# 2 -19.8   99.397385 -19.564255  0.174370  19.441765
# 3 -19.7   98.244460 -19.858267  0.731072  19.869267
# 4 -19.6   97.926956 -19.825966  0.273028  19.864285
# 5 -19.5   97.656450 -19.247020  0.565499  19.354967
# 6 -19.4   96.773270 -19.771715  0.529619  20.003057
# 7 -19.3   96.599434 -18.825197  0.962852  19.819378
# 8 -19.2   96.435640 -19.234894  0.580384  19.639378
# 9 -19.1   95.778680 -19.363642  0.776097  19.023579
# Ideal Functions
#       x        y1        y2        y3  ...       y47       y48       y49       y50
# ...
